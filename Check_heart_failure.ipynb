# %% [markdown]
# <a href="https://colab.research.google.com/github/Devu-Goyal/IDS-project/blob/main/Check_heart_failure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt                           # for analysing using figures
import seaborn as sns                                     # works on matplotlib for visualisations
import pandas as pd                                       # structuring data
import numpy as np                                        # for array
from sklearn.preprocessing import StandardScaler          # standardised data
from sklearn.model_selection import train_test_split      # split data in training and test data
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.svm import SVC                               # support vector machine
from sklearn.neighbors import KNeighborsClassifier        # K-nearest neighbour

# %% [markdown]
# # **Analysing data collected**

# %%
data = pd.read_csv('/content/heart_failure_clinical_records_dataset.csv')       # uploading data to pandas dataset
data.head(20)                                     # printing what we have uploaded
# Out:
#      age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0   75.0        0                       582  ...        0     4            1
# 1   55.0        0                      7861  ...        0     6            1
# 2   65.0        0                       146  ...        1     7            1
# 3   50.0        1                       111  ...        0     7            1
# 4   65.0        1                       160  ...        0     8            1
# 5   90.0        1                        47  ...        1     8            1
# 6   75.0        1                       246  ...        0    10            1
# 7   60.0        1                       315  ...        1    10            1
# 8   65.0        0                       157  ...        0    10            1
# 9   80.0        1                       123  ...        1    10            1
# 10  75.0        1                        81  ...        1    10            1
# 11  62.0        0                       231  ...        1    10            1
# 12  45.0        1                       981  ...        0    11            1
# 13  50.0        1                       168  ...        0    11            1
# 14  49.0        1                        80  ...        0    12            0
# 15  82.0        1                       379  ...        0    13            1
# 16  87.0        1                       149  ...        0    14            1
# 17  45.0        0                       582  ...        0    14            1
# 18  70.0        1                       125  ...        0    15            1
# 19  48.0        1                       582  ...        0    15            1
#
# [20 rows x 13 columns]

# %%
data.shape            # no. of rows and features in data set
# Out:
# (299, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data.describe()       # different statical values for features
# Out:
#               age     anaemia  ...        time  DEATH_EVENT
# count  299.000000  299.000000  ...  299.000000    299.00000
# mean    60.833893    0.431438  ...  130.260870      0.32107
# std     11.894809    0.496107  ...   77.614208      0.46767
# min     40.000000    0.000000  ...    4.000000      0.00000
# 25%     51.000000    0.000000  ...   73.000000      0.00000
# 50%     60.000000    0.000000  ...  115.000000      0.00000
# 75%     70.000000    1.000000  ...  203.000000      1.00000
# max     95.000000    1.000000  ...  285.000000      1.00000
#
# [8 rows x 13 columns]

# %%
# for getting relation between features
plt.figure(figsize=(15, 12))
sns.heatmap(data.corr(), annot=True, linewidths=2)
plt.show()

# %%
data['DEATH_EVENT'].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %% [markdown]
# # **Data before and After standardisation**

# %%
# Before
a = data.drop(columns = 'DEATH_EVENT', axis=1)    # Only features
b = data['DEATH_EVENT']                           # Only outcomes
print("")                      
print("-----------------Data Representing only Features before Standardization-------------------")
print("")
print(a)
print("")
print("")
print("")
print("-----------------Data Representing only Outcomes before Standardization-------------------")
print("")
print(b)
# Out:
# -----------------Data Representing only Features before Standardization-------------------
#
#       age  anaemia  creatinine_phosphokinase  ...  sex  smoking  time
# 0    75.0        0                       582  ...    1        0     4
# 1    55.0        0                      7861  ...    1        0     6
# 2    65.0        0                       146  ...    1        1     7
# 3    50.0        1                       111  ...    1        0     7
# 4    65.0        1                       160  ...    0        0     8
# ..    ...      ...                       ...  ...  ...      ...   ...
# 294  62.0        0                        61  ...    1        1   270
# 295  55.0        0                      1820  ...    0        0   271
# 296  45.0        0                      2060  ...    0        0   278
# 297  45.0        0                      2413  ...    1        1   280
# 298  50.0        0                       196  ...    1        1   285
#
# [299 rows x 12 columns]
#
#
#
# -----------------Data Representing only Outcomes before Standardization-------------------
#
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
# Doing Standardization
scaler = StandardScaler()
scaler.fit(a)
stnd_data = scaler.transform(a)
A = stnd_data                                 # whole dataset
B = data['DEATH_EVENT']                           # only outcomes
# After Standardization
print("")                      
print("-----------------Data Representing Outcomes + Features after Standardization-------------------")
print("")
print(A)
print("")
print("")
print("")
print("-----------------Data Representing only Outcomes after Standardization-------------------")
print("")
print(B)
# Out:
# -----------------Data Representing Outcomes + Features after Standardization-------------------
#
# [[ 1.19294523e+00 -8.71104775e-01  1.65728387e-04 ...  7.35688190e-01
#   -6.87681906e-01 -1.62950241e+00]
#  [-4.91279276e-01 -8.71104775e-01  7.51463953e+00 ...  7.35688190e-01
#   -6.87681906e-01 -1.60369074e+00]
#  [ 3.50832977e-01 -8.71104775e-01 -4.49938761e-01 ...  7.35688190e-01
#    1.45416070e+00 -1.59078490e+00]
#  ...
#  [-1.33339153e+00 -8.71104775e-01  1.52597865e+00 ... -1.35927151e+00
#   -6.87681906e-01  1.90669738e+00]
#  [-1.33339153e+00 -8.71104775e-01  1.89039811e+00 ...  7.35688190e-01
#    1.45416070e+00  1.93250906e+00]
#  [-9.12335403e-01 -8.71104775e-01 -3.98321274e-01 ...  7.35688190e-01
#    1.45416070e+00  1.99703825e+00]]
#
#
#
# -----------------Data Representing only Outcomes after Standardization-------------------
#
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %% [markdown]
# # **Splitting dataset into Training and Test-Set**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(A,B, test_size = 0.2, stratify=B, random_state=2)

# %%
print(X_train.shape)
print(X_train)
# Out:
# (239, 12)
# [[-1.16496908e+00 -8.71104775e-01  1.65728387e-04 ...  7.35688190e-01
#   -6.87681906e-01  9.12947806e-01]
#  [ 1.61400136e+00 -8.71104775e-01  2.00441579e-01 ... -1.35927151e+00
#   -6.87681906e-01 -3.36674053e-03]
#  [-4.91279276e-01 -8.71104775e-01  1.27821471e+00 ... -1.35927151e+00
#   -6.87681906e-01  1.81635651e+00]
#  ...
#  [-2.38645600e-01 -8.71104775e-01 -4.64391657e-01 ...  7.35688190e-01
#   -6.87681906e-01  1.28721713e+00]
#  [-6.59701727e-01  1.14796753e+00  1.29209447e-01 ...  7.35688190e-01
#    1.45416070e+00  1.01619452e+00]
#  [ 3.50832977e-01  1.14796753e+00 -2.85795151e-01 ...  7.35688190e-01
#   -6.87681906e-01 -5.58317804e-01]]

# %%
print(Y_train.shape)
print(Y_train)
# Out:
# (239,)
# 223    0
# 165    1
# 295    0
# 133    0
# 251    0
#       ..
# 58     1
# 140    1
# 257    0
# 233    0
# 100    0
# Name: DEATH_EVENT, Length: 239, dtype: int64

# %%
print(X_test.shape)
print(X_test)
# Out:
# (60, 12)
# [[-1.58602521e+00 -8.71104775e-01 -5.34591440e-01 -8.47579380e-01
#    1.62199114e-01 -7.35688190e-01 -7.61548671e-01 -6.71857022e-01
#    7.66063830e-01  7.35688190e-01 -6.87681906e-01  1.48080471e+00]
#  [ 9.81993013e-02 -8.71104775e-01 -5.69691331e-01  1.17983050e+00
#    1.85495776e+00  1.35927151e+00 -1.98258098e-01 -4.78204687e-01
#    5.39053835e-01  7.35688190e-01 -6.87681906e-01 -1.71142643e-01]
#  [-7.02231493e-02  1.14796753e+00 -5.01556248e-01  1.17983050e+00
#    1.85495776e+00  1.35927151e+00  7.82663649e-02 -6.71857022e-01
#   -1.41976151e-01 -1.35927151e+00 -6.87681906e-01 -4.67976933e-01]
#  [-1.58602521e+00 -8.71104775e-01 -5.34591440e-01 -8.47579380e-01
#   -6.84180207e-01 -7.35688190e-01 -4.95265854e-01  2.32975417e+00
#   -1.95805611e+00  7.35688190e-01  1.45416070e+00  1.54533390e+00]
#  [ 7.71889104e-01 -8.71104775e-01 -4.74715155e-01  1.17983050e+00
#    5.85388775e-01  1.35927151e+00  2.11407773e-01 -9.09000174e-02
#   -1.41976151e-01  7.35688190e-01  1.45416070e+00 -1.34557396e+00]
#  [-1.33339153e+00 -8.71104775e-01  1.65728387e-04  1.17983050e+00
#   -7.07675018e-03  1.35927151e+00  7.53566018e-09 -2.07091418e-01
#    8.50338444e-02 -1.35927151e+00 -6.87681906e-01  7.06454387e-01]
#  [ 1.19294523e+00 -8.71104775e-01  1.65728387e-04 -8.47579380e-01
#    1.62199114e-01 -7.35688190e-01  7.53566018e-09 -2.07091418e-01
#    8.50338444e-02  7.35688190e-01 -6.87681906e-01 -3.00201030e-01]
#  [ 1.19294523e+00  1.14796753e+00 -3.91094825e-01  1.17983050e+00
#   -7.07675018e-03  1.35927151e+00  2.01166126e-01 -7.68683190e-01
#   -1.27702613e+00  7.35688190e-01  1.45416070e+00 -7.26093707e-01]
#  [ 6.03466653e-01  1.14796753e+00 -4.38582914e-01  1.17983050e+00
#    1.85495776e+00 -7.35688190e-01 -5.66957382e-01 -3.81378520e-01
#    7.66063830e-01 -1.35927151e+00 -6.87681906e-01  1.37755800e+00]
#  [ 9.81993013e-02  1.14796753e+00  7.55272598e-02 -8.47579380e-01
#    1.62199114e-01 -7.35688190e-01  2.01166126e-01 -6.71857022e-01
#   -8.23006137e-01 -1.35927151e+00 -6.87681906e-01  1.32593464e+00]
#  [-9.12335403e-01  1.14796753e+00 -2.93021599e-01 -8.47579380e-01
#   -2.60990546e-01 -7.35688190e-01  1.01025622e+00 -4.78204687e-01
#    7.66063830e-01  7.35688190e-01  1.45416070e+00  1.41627551e+00]
#  [ 2.11926871e+00 -8.71104775e-01  1.65728387e-04 -8.47579380e-01
#   -7.07675018e-03 -7.35688190e-01  7.53566018e-09  4.22278670e-01
#   -5.95996141e-01 -1.35927151e+00 -6.87681906e-01 -4.55071094e-01]
#  [ 3.50832977e-01 -8.71104775e-01 -2.64115807e-01 -8.47579380e-01
#   -7.07675018e-03 -7.35688190e-01  3.13824241e-01  2.96404652e-01
#    5.39053835e-01 -1.35927151e+00 -6.87681906e-01  1.15815874e+00]
#  [-1.33339153e+00 -8.71104775e-01  1.65728387e-04 -8.47579380e-01
#   -1.53055953e+00  1.35927151e+00 -1.40677242e+00  1.99578485e-01
#   -3.68986146e-01  7.35688190e-01 -6.87681906e-01  6.41925193e-01]
#  [-4.91279276e-01 -8.71104775e-01 -5.38720839e-01 -8.47579380e-01
#   -2.60990546e-01 -7.35688190e-01 -3.62124446e-01 -1.87726185e-01
#   -3.68986146e-01  7.35688190e-01  1.45416070e+00 -5.19600288e-01]
#  [ 1.61400136e+00 -8.71104775e-01  1.65728387e-04  1.17983050e+00
#   -2.60990546e-01 -7.35688190e-01  8.87356460e-01  6.83709322e-01
#   -5.95996141e-01  7.35688190e-01 -6.87681906e-01  5.64490161e-01]
#  [-9.12335403e-01  1.14796753e+00 -4.28259416e-01  1.17983050e+00
#    5.85388775e-01 -7.35688190e-01  1.01025622e+00 -3.81378520e-01
#   -1.41976151e-01 -1.35927151e+00 -6.87681906e-01  7.32266064e-01]
#  [-1.54434375e-01  1.14796753e+00 -3.11603895e-01  1.17983050e+00
#   -1.10736987e+00  1.35927151e+00  3.95757415e-01 -3.81378520e-01
#    9.93073825e-01 -1.35927151e+00 -6.87681906e-01 -6.74470352e-01]
#  [ 4.35044203e-01  1.14796753e+00 -5.30462041e-01  1.17983050e+00
#   -7.07675018e-03  1.35927151e+00 -1.03807313e+00 -3.81378520e-01
#   -1.41976151e-01 -1.35927151e+00 -6.87681906e-01 -4.55071094e-01]
#  [-7.02231493e-02 -8.71104775e-01  2.14125910e+00  1.17983050e+00
#   -6.84180207e-01 -7.35688190e-01  4.26482355e-01  8.77361657e-01
#    8.50338444e-02  7.35688190e-01 -6.87681906e-01 -1.29395061e+00]
#  [-1.75444766e+00 -8.71104775e-01 -3.48768486e-01 -8.47579380e-01
#    5.85388775e-01  1.35927151e+00  1.19232952e-01 -4.78204687e-01
#    7.66063830e-01 -1.35927151e+00 -6.87681906e-01  5.64490161e-01]
#  [-9.12335403e-01 -8.71104775e-01  9.97415583e-01 -8.47579380e-01
#   -6.84180207e-01  1.35927151e+00 -5.36232442e-01 -5.75030855e-01
#    3.12043840e-01  7.35688190e-01 -6.87681906e-01 -2.87295191e-01]
#  [ 1.19294523e+00  1.14796753e+00 -3.46703786e-01 -8.47579380e-01
#   -1.95374919e+00 -7.35688190e-01 -1.39653077e+00 -1.87726185e-01
#    8.50338444e-02  7.35688190e-01 -6.87681906e-01 -1.55206738e+00]
#  [ 3.50832977e-01  1.14796753e+00 -4.61294608e-01 -8.47579380e-01
#   -2.60990546e-01  1.35927151e+00  2.72857654e-01 -5.75030855e-01
#   -5.95996141e-01  7.35688190e-01 -6.87681906e-01  8.22606935e-01]
#  [ 1.78242381e+00  1.14796753e+00  2.81997209e-01  1.17983050e+00
#    1.00857844e+00  1.35927151e+00  5.90348704e-01 -3.81378520e-01
#    1.90111381e+00 -1.35927151e+00 -6.87681906e-01 -1.29395061e+00]
#  [ 7.71889104e-01  1.14796753e+00 -5.39753189e-01 -8.47579380e-01
#    1.85495776e+00 -7.35688190e-01 -8.55999835e-02 -2.84552352e-01
#   -1.41976151e-01 -1.35927151e+00 -6.87681906e-01 -5.84129481e-01]
#  [-1.54434375e-01 -8.71104775e-01 -5.32526741e-01  1.17983050e+00
#   -1.53055953e+00 -7.35688190e-01 -1.98030464e+00  9.74187825e-01
#   -5.95996141e-01  7.35688190e-01 -6.87681906e-01  6.11624529e-02]
#  [-9.12335403e-01  1.14796753e+00 -5.44914937e-01 -8.47579380e-01
#    1.62199114e-01 -7.35688190e-01  1.60199539e-01 -5.75030855e-01
#    9.93073825e-01  7.35688190e-01 -6.87681906e-01  1.54533390e+00]
#  [ 3.50832977e-01 -8.71104775e-01  3.20194150e-01  1.17983050e+00
#   -2.60990546e-01 -7.35688190e-01  7.53566018e-09 -2.84552352e-01
#    1.22008382e+00 -1.35927151e+00 -6.87681906e-01  1.62276893e+00]
#  [-1.58602521e+00 -8.71104775e-01  4.77684800e+00 -8.47579380e-01
#   -6.84180207e-01 -7.35688190e-01 -3.82607740e-01 -3.81378520e-01
#    7.66063830e-01  7.35688190e-01  1.45416070e+00 -5.58317804e-01]
#  [ 2.66621752e-01  1.14796753e+00 -5.36656139e-01 -8.47579380e-01
#    1.85495776e+00 -7.35688190e-01  4.67448942e-01  1.02752318e-01
#   -3.68986146e-01 -1.35927151e+00 -6.87681906e-01  5.64490161e-01]
#  [-9.12335403e-01 -8.71104775e-01 -1.03069246e-01  1.17983050e+00
#   -6.84180207e-01 -7.35688190e-01  6.72281878e-01 -4.78204687e-01
#   -1.05001613e+00 -1.35927151e+00 -6.87681906e-01 -2.74389353e-01]
#  [-7.02231493e-02  1.14796753e+00  1.60179939e-01 -8.47579380e-01
#    1.85495776e+00  1.35927151e+00 -5.46474088e-01  1.02752318e-01
#   -3.68986146e-01  7.35688190e-01  1.45416070e+00 -4.55071094e-01]
#  [-7.02231493e-02  1.14796753e+00 -5.02588598e-01 -8.47579380e-01
#    1.85495776e+00 -7.35688190e-01  7.54215052e-01 -3.81378520e-01
#    3.12043840e-01  7.35688190e-01  1.45416070e+00  2.03126678e-01]
#  [ 3.50832977e-01 -8.71104775e-01  1.65728387e-04  1.17983050e+00
#    1.62199114e-01 -7.35688190e-01  6.80247182e-02 -3.81378520e-01
#    3.12043840e-01 -1.35927151e+00 -6.87681906e-01  1.25691646e-01]
#  [-3.22856825e-01  1.14796753e+00 -4.67488707e-01 -8.47579380e-01
#   -6.84180207e-01 -7.35688190e-01  1.34823057e+00 -3.81378520e-01
#    7.66063830e-01 -1.35927151e+00 -6.87681906e-01 -1.13908054e+00]
#  [ 2.03505748e+00 -8.71104775e-01 -5.76917780e-01 -8.47579380e-01
#    5.85388775e-01 -7.35688190e-01  9.89772928e-01  1.55514483e+00
#   -1.05001613e+00  7.35688190e-01 -6.87681906e-01 -1.31976229e+00]
#  [-7.02231493e-02 -8.71104775e-01 -5.45947287e-01 -8.47579380e-01
#    1.00857844e+00  1.35927151e+00  2.31891067e-01  8.77361657e-01
#    1.44709382e+00 -1.35927151e+00 -6.87681906e-01 -5.58317804e-01]
#  [ 1.82410527e-01  1.14796753e+00 -5.37688489e-01  1.17983050e+00
#    1.62199114e-01 -7.35688190e-01 -4.33815974e-01 -2.84552352e-01
#    7.66063830e-01 -1.35927151e+00 -6.87681906e-01 -5.71223642e-01]
#  [ 6.03466653e-01  1.14796753e+00 -3.73544880e-01 -8.47579380e-01
#   -2.60990546e-01  1.35927151e+00  2.62616007e-01 -4.78204687e-01
#    7.66063830e-01  7.35688190e-01  1.45416070e+00 -1.42300900e+00]
#  [-1.54434375e-01  1.14796753e+00 -4.18968268e-01  1.17983050e+00
#   -1.10736987e+00 -7.35688190e-01 -4.33815974e-01 -3.81378520e-01
#   -1.41976151e-01  7.35688190e-01  1.45416070e+00  2.54750033e-01]
#  [-7.02231493e-02 -8.71104775e-01 -5.01556248e-01  1.17983050e+00
#   -7.07675018e-03 -7.35688190e-01 -3.62124446e-01 -6.23443938e-01
#    7.66063830e-01 -1.35927151e+00 -6.87681906e-01 -4.55071094e-01]
#  [ 1.78242381e+00  1.14796753e+00 -2.09401270e-01 -8.47579380e-01
#    1.00857844e+00 -7.35688190e-01 -2.21586251e+00 -9.09000174e-02
#   -1.41976151e-01  7.35688190e-01 -6.87681906e-01 -1.51334987e+00]
#  [-7.43912952e-01 -8.71104775e-01 -4.64391657e-01 -8.47579380e-01
#   -6.84180207e-01 -7.35688190e-01 -4.64540914e-01 -6.71857022e-01
#   -1.41976151e-01  7.35688190e-01  1.45416070e+00 -2.35671837e-01]
#  [-2.38645600e-01  1.14796753e+00 -1.87721925e-01 -8.47579380e-01
#    1.62199114e-01 -7.35688190e-01 -1.01758984e+00 -3.81378520e-01
#    5.39053835e-01 -1.35927151e+00 -6.87681906e-01 -5.06694449e-01]
#  [-4.91279276e-01 -8.71104775e-01  1.48158761e+00 -8.47579380e-01
#   -1.10736987e+00 -7.35688190e-01  5.18657176e-01 -2.84552352e-01
#    3.12043840e-01  7.35688190e-01 -6.87681906e-01  1.08072371e+00]
#  [-7.43912952e-01  1.14796753e+00 -5.40785538e-01 -8.47579380e-01
#   -2.60990546e-01 -7.35688190e-01  1.39716246e-01  5.92615005e-03
#   -1.41976151e-01 -1.35927151e+00 -6.87681906e-01 -1.32425127e-01]
#  [-2.38645600e-01 -8.71104775e-01  1.65728387e-04  1.17983050e+00
#   -1.10736987e+00 -7.35688190e-01  2.46457006e+00 -3.81378520e-01
#    3.12043840e-01  7.35688190e-01 -6.87681906e-01  9.64571161e-01]
#  [ 1.82410527e-01  1.14796753e+00 -4.94329800e-01  1.17983050e+00
#   -2.60990546e-01 -7.35688190e-01 -8.63965138e-01 -4.78204687e-01
#   -1.41976151e-01  7.35688190e-01  1.45416070e+00  1.80345067e+00]
#  [-6.59701727e-01  1.14796753e+00  1.26582652e+00 -8.47579380e-01
#    1.85495776e+00  1.35927151e+00 -1.47049864e-01 -6.71857022e-01
#    3.12043840e-01  7.35688190e-01  1.45416070e+00 -3.13106869e-01]
#  [-5.75490501e-01  1.14796753e+00 -1.59848482e-01 -8.47579380e-01
#    2.70133708e+00  1.35927151e+00 -1.15073125e+00  7.36471488e+00
#    8.50338444e-02 -1.35927151e+00 -6.87681906e-01  8.48418612e-01]
#  [ 1.19294523e+00 -8.71104775e-01 -4.98459199e-01 -8.47579380e-01
#   -7.07675018e-03  1.35927151e+00 -4.03091033e-01  1.07101399e+00
#   -5.95996141e-01  7.35688190e-01 -6.87681906e-01  4.09620097e-01]
#  [ 7.71889104e-01 -8.71104775e-01 -3.81803678e-01  1.17983050e+00
#   -1.78447332e+00  1.35927151e+00  1.28678068e+00 -3.81378520e-01
#   -1.41976151e-01  7.35688190e-01  1.45416070e+00  7.45171903e-01]
#  [ 9.40311555e-01  1.14796753e+00 -4.87103352e-01 -8.47579380e-01
#   -1.10736987e+00 -7.35688190e-01  1.08991305e-01 -3.81378520e-01
#    7.66063830e-01  7.35688190e-01  1.45416070e+00 -8.42246255e-01]
#  [ 3.50832977e-01 -8.71104775e-01  1.65728387e-04  1.17983050e+00
#   -6.84180207e-01 -7.35688190e-01 -1.47049864e-01 -9.09000174e-02
#   -1.41976151e-01  7.35688190e-01  1.45416070e+00  1.05491203e+00]
#  [-7.02231493e-02  1.14796753e+00  6.35982686e-03  1.17983050e+00
#    1.85495776e+00 -7.35688190e-01 -7.10340437e-01 -2.84552352e-01
#    1.22008382e+00 -1.35927151e+00 -6.87681906e-01 -1.25523309e+00]
#  [ 3.50832977e-01  1.14796753e+00 -5.30462041e-01  1.17983050e+00
#    1.85495776e+00  1.35927151e+00  4.16240709e-01 -5.75030855e-01
#    7.66063830e-01  7.35688190e-01 -6.87681906e-01 -6.61564513e-01]
#  [ 1.61400136e+00 -8.71104775e-01 -4.47874061e-01  1.17983050e+00
#   -7.07675018e-03 -7.35688190e-01 -1.17121454e+00  4.90056987e-01
#    1.67410381e+00  7.35688190e-01  1.45416070e+00 -1.38429148e+00]
#  [-1.24918030e+00 -8.71104775e-01 -4.27227066e-01  1.17983050e+00
#   -1.78447332e+00  1.35927151e+00  7.82663649e-02  6.83709322e-01
#   -2.86609609e+00 -1.35927151e+00 -6.87681906e-01 -3.90541901e-01]
#  [-7.02231493e-02  1.14796753e+00  2.59744720e-02 -8.47579380e-01
#    1.62199114e-01 -7.35688190e-01 -4.85024208e-01 -7.68683190e-01
#    3.12043840e-01  7.35688190e-01  1.45416070e+00 -9.84210480e-01]]

# %%
print(Y_test.shape)
print(Y_test)
# Out:
# (60,)
# 273    0
# 151    0
# 116    0
# 282    0
# 27     1
# 196    0
# 135    0
# 78     0
# 263    0
# 261    0
# 265    0
# 119    1
# 256    0
# 194    1
# 111    0
# 190    0
# 205    0
# 84     1
# 121    0
# 38     0
# 189    0
# 139    0
# 6      1
# 214    0
# 37     1
# 97     0
# 167    1
# 284    0
# 288    0
# 103    0
# 191    0
# 142    0
# 120    0
# 175    0
# 168    0
# 49     1
# 31     1
# 104    0
# 99     0
# 22     1
# 181    1
# 122    0
# 15     1
# 146    0
# 115    0
# 246    1
# 156    0
# 224    0
# 293    0
# 130    0
# 217    1
# 183    1
# 210    0
# 67     1
# 241    0
# 44     1
# 87     0
# 25     1
# 126    1
# 57     0
# Name: DEATH_EVENT, dtype: int64

# %% [markdown]
# # **Training datasets using SVM and KNN**

# %%
# for displaying Confusion matrix
def displaying(y_test, y_prdct)->float:
  acc = accuracy_score(y_test, y_prdct)
  matrix = confusion_matrix(y_test, y_prdct)
  sns.heatmap(matrix, annot=True, fmt="d")
  plt.title(f"Accuracy: {acc:0.4f}")
  plt.xlabel("Predicted labels")
  plt.ylabel("Actual labels")
  plt.show()
  return acc

def classify(clsf, x_train=X_train, y_train=Y_train, x_test=X_test, y_test=Y_test)->float:
  clsf.fit(x_train, y_train)
  y_prdct = clsf.predict(x_test)
  acc = displaying(y_test, y_prdct)
  print(classification_report(y_test, y_prdct))
  return acc

# %%
# Using Linear SVM as our classification model
model = SVC(kernel="linear", random_state=0)
model_acc = classify(model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        41
#            1       0.75      0.63      0.69        19
#
#     accuracy                           0.82        60
#    macro avg       0.80      0.77      0.78        60
# weighted avg       0.81      0.82      0.81        60

# %%
# Using KNN as our classification model
model = KNeighborsClassifier(n_neighbors=5, metric="minkowski", p=2)
model_acc = classify(model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.98      0.87        41
#            1       0.89      0.42      0.57        19
#
#     accuracy                           0.80        60
#    macro avg       0.84      0.70      0.72        60
# weighted avg       0.82      0.80      0.78        60

# %% [markdown]
# # **Constructing a generalised Predecting System**

# %%
# just predecting whether the person is diabetic or not
input = (69, 1, 669, 0, 19, 0, 696969, 1.6, 125, 1, 0, 16)

data_array = np.asarray(input)                    # making numpy array
data_reshape = data_array.reshape(1, -1)          # data reshaping coz predecting for an instance

stnd_data = scaler.transform(data_reshape)             # standardising data
print(stnd_data)

# selecting SVM classifier
classifier = SVC(kernel='linear')
classifier.fit(X_train, Y_train)

prediction = classifier.predict(stnd_data)
print(prediction)

if(prediction[0]==0):
  print("----------------------Heart won't fail----------------------------")
else:
  print("------------------------Heart-faliure-----------------------------")
# Out:
# [[ 0.68767788  1.14796753  0.08998016 -0.84757938 -1.61519746 -0.73568819
#    4.4408904   0.19957848 -2.6390861   0.73568819 -0.68768191 -1.47463235]]
# [1]
# ------------------------Heart-faliure-----------------------------
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
